# %% [markdown]
# ### 更新Psmstr、PTmstr、Wod、rule 等寄存csv資料用

# %%
import pymssql
import pandas as pd
import warnings
from sqlalchemy import create_engine
import datetime
engine = create_engine(f'mssql+pyodbc://plis:spl_20765242@77.0.0.151/plQuote_train?driver=ODBC Driver 17 for SQL Server')
conn = pymssql.connect(
    host = '77.0.0.151',
    user = 'plis',
    password = 'spl_20765242',
    database = 'plQuote_train'
)
cursor = conn.cursor(as_dict=True)

# %%
# rulefile = "rule1011.csv"
rulefile = "零件自動報價資料(中英說明)V1.csv"

# %%
current_date = datetime.date.today()
current_date = current_date.strftime("%m%d")
file_name = {}
file_name["Psmstr"] = f"Psmstr{current_date}.csv"
file_name["Wod"] = f"Wod{current_date}.csv"
file_name["PTmstr"] = f"PTmstr{current_date}.csv"
file_name["rule_clean"] = f"rule_clean{current_date}.csv"

# %%
selectPsmstr = ("select Ps_par as 父件, Ps_comp as	子件, pt_desc1 as 中文說明1, pt_desc2 as 中文說明2, xen_desc1 as 英文說明1, xen_desc2 as 英文說明2, pt_group as 組別,Ps_op as 作業碼, Ps_qty_per as	單位數量 from ps_mstr Join pt_mstr On pt_part = Ps_comp left join xen_mstr on ps_comp = xen_part where (Ps_start <= GETDATE() or Ps_start is null) and (Ps_end >= GETDATE() or Ps_end is null)")
cursor.execute(selectPsmstr)
result=cursor.fetchall()
psmstr = pd.DataFrame(result)

# %%
psmstr
# Out:
#                         父件             子件          中文說明1           中文說明2  \
# 0        Y-BTEU1213X320963  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 1        Y-BTEU1213X341083  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 2        Y-BTEU1215X300901  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 3        Y-BTGF1213X300840  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 4        Y-BTGK1111X300420  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# ...                    ...            ...            ...             ...
# 766090   Y-BTEQ3210X140560  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 766091   Y-BTEQ3210X200800  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 766092  Y-BTEQA3210X140560  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 766093   Y-BTES1213X200800  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
# 766094   Y-BTEU1213X300903  9BI03-S004-01  送紗調整架-S004-低腳  022.000.079.01
#
#                         英文說明1 英文說明2    組別   作業碼  單位數量
# 0       Toothed belt adjuster        BI03  2902  3.00
# 1       Toothed belt adjuster        BI03  2902  3.00
# 2       Toothed belt adjuster        BI03  2902  3.00
# 3       Toothed belt adjuster        BI03  2902  2.00
# 4       Toothed belt adjuster        BI03  2902  3.00
# ...                       ...   ...   ...   ...   ...
# 766090  Toothed belt adjuster        BI03  2902  2.00
# 766091  Toothed belt adjuster        BI03  2902  2.00
# 766092  Toothed belt adjuster        BI03  2902  2.00
# 766093  Toothed belt adjuster        BI03  2902  2.00
# 766094  Toothed belt adjuster        BI03  2902  3.00
#
# [766095 rows x 9 columns]

# %%
selectWod = ("Select Wod_part as 子件,  pt_desc1 as 中文說明1, pt_desc2 as 中文說明2, xen_desc1 as 英文說明1, xen_desc2 as 英文說明2, Pt_mstr.Pt_group as 組別,  Wod_qty_iss as 發料量, wod_code as 機號 from wod_det join pt_mstr on wod_part = pt_mstr.pt_part left join xen_mstr on Wod_part = xen_part")
cursor.execute(selectWod)
result=cursor.fetchall()
wod = pd.DataFrame(result)

# %%
wod
# Out:
#                          子件              中文說明1               中文說明2  \
# 0        S-EU34-3280-00-001               探布桿組     KS3B、KS4B-機台探布用
# 1          CDC30-A7303-00-0   無馬達控制箱-30"車7.5HP      380V旭優;陽春型 K系列
# 2          DC30-7127-C0-001      30"34"40"下支腳門  AS3B-34"車配加高100mm用
# 3          DC30-7131-00-003             馬達支腳護蓋         A系列30~40吋車台
# 4          DC30-7182-00-003             下支腳防塵蓋         A系列30~40吋車台
# ...                     ...                ...                 ...
# 2923886  S-EL34-7146-00-001         護網配件組(A系列)         A系列:13"-40"
# 2923887  S-EL34-7400-00-001  馬達傳動組;配98M65-0880          A系列用皮帶輪280
# 2923888  S-EU30-2302-00-001           四角管骨幹加強組                 支撐架
# 2923889  S-EU30-7250-00-003             方向機把手組              A 機台順轉
# 2923890  S-EU30-7300-00-005               主傳動組         A 單面機台 , 順轉
#
#                            英文說明1     英文說明2    組別  發料量        機號
# 0            Fabric Detector set            3280  3.0  A1100725
# 1               Control Unit380v            9000  1.0  A1100725
# 2                 DOOR(side leg)  AS3B-34"  7127  2.0  A1100725
# 3        DUST COVER(DRIVING LEG)   30"~40"  7131  1.0  A1100725
# 4           DUST COVER(side leg)   30"~40"  7182  2.0  A1100725
# ...                          ...       ...   ...  ...       ...
# 2923886                NET HINGE            7146  1.0  A1100725
# 2923887    Motor Hold UnitE；AS3B            7400  1.0  A1100725
# 2923888              SQUARE PIPE            2302  1.0  A1100725
# 2923889              Handle Unit            7250  1.0  A1100725
# 2923890      MAIN SHAFT ASSEMBLY            7300  1.0  A1100725
#
# [2923891 rows x 8 columns]

# %%
selectPTmstr = ("select pt_part as 子件, pt_desc1 as 中文說明1, pt_desc2 as 中文說明2 , xen_desc1 as 英文說明1, xen_desc2 as 英文說明2, pt_group as 組別 from pt_mstr left join xen_mstr on pt_part = xen_part")
cursor.execute(selectPTmstr)
result=cursor.fetchall()
PTmstr = pd.DataFrame(result)

# %%
PTmstr
# Out:
#                         子件                    中文說明1             中文說明2  \
# 0                   001167       XSDP 30"x16Gx42F*3           新克兩面毛巾機
# 1                   001169       XSDP 30"x16Gx42F*3           新克兩面毛巾機
# 2                   001174       XSDP 30"x16Gx42F*3           新克兩面毛巾機
# 3                   001178        XS3B 34"x28Gx102F       新克4段針織機(合梢)
# 4                   001181  FD2.5B/T(P) 30"x28Gx72F     齒輪兩面全能針織機上2下4
# ...                    ...                      ...               ...
# 129406           KN9230 C1          下直條針-FDSPS:毛長=0  G630-5108H-4:22G
# 129407  RB-02-1916038-001S       XRA/CE-19"X16GX38F             生產BOM
# 129408  TP-01-3024048-002S      KSCS4/C-30"X24GX48F             生產BOM
# 129409              001120    XSDP-DS 30"x14Gx42F*3           新克兩面毛巾機
# 129410              000827      XDCJ-AP 34"x20Gx54F      雙面電腦提花機 WAC式
#
#                            英文說明1 英文說明2    組別
# 0            XSDP 30"x16Gx42F*3         MSPA
# 1            XSDP 30"x16Gx42F*3         MSPA
# 2            XSDP 30"x16Gx42F*3         MSPA
# 3             XS3B 34"x28Gx102F         MSIE
# 4       FD2.5B/T(P) 30"x28Gx72F         MDD7
# ...                          ...   ...   ...
# 129406                      None  None    D8
# 129407                      None  None  MDRB
# 129408                      None  None  MSCE
# 129409                      None  None  MSPA
# 129410                      None  None  MDC9
#
# [129411 rows x 6 columns]

# %%
rule = pd.read_csv(rulefile)
rule
# Out:
#         機種   吋  口數    零件包料號                               名稱(中文)  \
# 0     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 1     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 2     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 3     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 4     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# ...    ...  ..  ..      ...                                  ...
# 1555  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1556  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1557  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1558  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1559  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
#
#                                        名稱(英文)            零件      說明    量  \
# 0                 Rack hold plate servicepack      9MN00-M6      螺帽  6.0
# 1                 Rack hold plate servicepack     E130-3231   舌片圈壓片  6.0
# 2                 Rack hold plate servicepack    9PI00-4X10      直鞘  6.0
# 3                 Rack hold plate servicepack   9SC01-M5X10    有頭螺絲  6.0
# 4                 Rack hold plate servicepack   9SC02-M6X16    無頭螺絲  6.0
# ...                                       ...           ...     ...  ...
# 1555  Motor gear unit space plate servicepack  9KE01-8X6X15   鍵-雙頭圓  1.0
# 1556  Motor gear unit space plate servicepack     M330-7305      壓蓋  2.0
# 1557  Motor gear unit space plate servicepack    9MN06-0030    齒形螺帽  1.0
# 1558  Motor gear unit space plate servicepack    9MROA-0047  戒子-S47  2.0
# 1559  Motor gear unit space plate servicepack    9MW06-0030     太陽片  1.0
#
#              參照對象  參照倍數    參照類別 料號變動依據       中文說明1        中文說明2  \
# 0     3231,-1501-     1  *組別或料號    NaN          螺帽          NaN
# 1            車台工單     1    車台工單    NaN       舌片圈壓片       2.00mm
# 2     3231,-1501-     1  *組別或料號    NaN  直鞘-4X10長鋼珠     HARDWARE
# 3     3231,-1501-     1  *組別或料號    NaN        有頭螺絲     HARDWARE
# 4     3231,-1501-     1  *組別或料號    NaN        無頭螺絲     HARDWARE
# ...           ...   ...     ...    ...         ...          ...
# 1555           固定     1      固定    NaN       鍵-雙頭圓  8x6mmx15mmL
# 1556       S-7500     1     *S-    NaN          壓蓋     06"--40"
# 1557           固定     1      固定    NaN        齒形螺帽         KM06
# 1558           固定     2      固定    NaN      戒子-S47         S-47
# 1559           固定     1      固定    NaN         太陽片         MB06
#
#               英文說明1         英文說明2
# 0               Nut      m8x1.25p
# 1        Hold plate           NaN
# 2     Straight Pin           4x10
# 3             Screw         M5X10
# 4            Screw          M6X16
# ...             ...           ...
# 1555   Keyway8x6x15           NaN
# 1556          Cover  Length:750mm
# 1557           Nut           KM06
# 1558       RingS-47           NaN
# 1559        Washer           MB06
#
# [1560 rows x 17 columns]

# %%
error = []
# 根據PTmstr更新rule中每個零件的中英文說明
for index, Row in rule.iterrows():
    if len(PTmstr[PTmstr['子件']==Row['零件']])==0:
        error.append(Row['零件']) # 檢查零件包內錯誤料號
        print(Row['零件'],"不存在")

# %%
rule
# Out:
#         機種   吋  口數    零件包料號                               名稱(中文)  \
# 0     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 1     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 2     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 3     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# 4     KS3B  30  90   3000-1       3231 servicepack#1(舌片圈支架壓片零件包)
# ...    ...  ..  ..      ...                                  ...
# 1555  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1556  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1557  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1558  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
# 1559  XD2B  34  72  7000-13  7507 servicepack#13(馬達皮帶齒輪組皮帶隔板零件包)
#
#                                        名稱(英文)            零件      說明    量  \
# 0                 Rack hold plate servicepack      9MN00-M6      螺帽  6.0
# 1                 Rack hold plate servicepack     E130-3231   舌片圈壓片  6.0
# 2                 Rack hold plate servicepack    9PI00-4X10      直鞘  6.0
# 3                 Rack hold plate servicepack   9SC01-M5X10    有頭螺絲  6.0
# 4                 Rack hold plate servicepack   9SC02-M6X16    無頭螺絲  6.0
# ...                                       ...           ...     ...  ...
# 1555  Motor gear unit space plate servicepack  9KE01-8X6X15   鍵-雙頭圓  1.0
# 1556  Motor gear unit space plate servicepack     M330-7305      壓蓋  2.0
# 1557  Motor gear unit space plate servicepack    9MN06-0030    齒形螺帽  1.0
# 1558  Motor gear unit space plate servicepack    9MROA-0047  戒子-S47  2.0
# 1559  Motor gear unit space plate servicepack    9MW06-0030     太陽片  1.0
#
#              參照對象  參照倍數    參照類別 料號變動依據       中文說明1        中文說明2  \
# 0     3231,-1501-     1  *組別或料號    NaN          螺帽          NaN
# 1            車台工單     1    車台工單    NaN       舌片圈壓片       2.00mm
# 2     3231,-1501-     1  *組別或料號    NaN  直鞘-4X10長鋼珠     HARDWARE
# 3     3231,-1501-     1  *組別或料號    NaN        有頭螺絲     HARDWARE
# 4     3231,-1501-     1  *組別或料號    NaN        無頭螺絲     HARDWARE
# ...           ...   ...     ...    ...         ...          ...
# 1555           固定     1      固定    NaN       鍵-雙頭圓  8x6mmx15mmL
# 1556       S-7500     1     *S-    NaN          壓蓋     06"--40"
# 1557           固定     1      固定    NaN        齒形螺帽         KM06
# 1558           固定     2      固定    NaN      戒子-S47         S-47
# 1559           固定     1      固定    NaN         太陽片         MB06
#
#               英文說明1         英文說明2
# 0               Nut      m8x1.25p
# 1        Hold plate           NaN
# 2     Straight Pin           4x10
# 3             Screw         M5X10
# 4            Screw          M6X16
# ...             ...           ...
# 1555   Keyway8x6x15           NaN
# 1556          Cover  Length:750mm
# 1557           Nut           KM06
# 1558       RingS-47           NaN
# 1559        Washer           MB06
#
# [1560 rows x 17 columns]

# %%
for e in error:
    print(e)

# %%
psmstr.to_csv(file_name["Psmstr"],index=False)
wod.to_csv(file_name["Wod"],index=False)
PTmstr.to_csv(file_name["PTmstr"],index=False)
rule.to_csv(file_name["rule_clean"],index=False)
